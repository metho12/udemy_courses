# %% [markdown]
# # import libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read Data

# %%
df = pd.read_csv('udemy_courses.csv')
df
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %% [markdown]
# # Get some information about the data

# %%
df.head(5)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %%
df.sample(10)
# Out:
#       course_id                                       course_title  \
# 3584     169144        How to easily Manage your WordPress Website
# 219      476256     Stock Options Trades Using Interactive Brokers
# 2539     425910  How to Optimise Your WordPress Website's Speed...
# 1773    1227748  create stunning Photoshop compositions in minutes
# 2082     584468  Instant Harmonica - play The Kesh (part 2) - e...
# 3504    1007766  How to create Paypal and Credit card Payment B...
# 3187    1075662              Learning Docker and Kubernetes by Lab
# 470     1220862  The True ' Secret Sauce  For Stock Market Succ...
# 730      874312  Cashflow Management for Small Businesses: A Ho...
# 2294     762240     Guitar Lessons - Two Handed Tapping Essentials
#
#                                                     url  is_paid  price  \
# 3584    https://www.udemy.com/manage-wordpress-website/     True     20
# 219   https://www.udemy.com/stock-options-trades-usi...     True     95
# ...

# %%
df.describe()
# Out:
#           course_id        price  num_subscribers   num_reviews  num_lectures  \
# count  3.678000e+03  3678.000000      3678.000000   3678.000000   3678.000000
# mean   6.759720e+05    66.049483      3197.150625    156.259108     40.108755
# std    3.432732e+05    61.005755      9504.117010    935.452044     50.383346
# min    8.324000e+03     0.000000         0.000000      0.000000      0.000000
# 25%    4.076925e+05    20.000000       111.000000      4.000000     15.000000
# 50%    6.879170e+05    45.000000       911.500000     18.000000     25.000000
# 75%    9.613555e+05    95.000000      2546.000000     67.000000     45.750000
# max    1.282064e+06   200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration
# count       3678.000000
# mean           4.094517
# std            6.053840
# min            0.000000
# 25%            1.000000
# 50%            2.000000
# 75%            4.500000
# max           78.500000

# %% [markdown]
# # Data Cleaning
#    - null
#    - duplicate
#    - remove unnecessary columns
#    - column types
#    - relation categorical columns

# %%
df.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
df.sample(10)
# Out:
#       course_id                                       course_title  is_paid  \
# 2194     628606  Piano Lessons for Beginners: Play the Piano AN...     True
# 617      304414                                Bookkeeping Systems     True
# 2277     854694  Instant Harmonica - play Star Wars + the Lion ...     True
# 532      972126  Forex Trading Masterclass - Learn To Trade Better     True
# 3514     825752                  Angular 2 - Superheroic Framework     True
# 2849     446608                  AJAX : Let's build a COOL project     True
# 2591     842728          Getting Started with NodeJS for Beginners     True
# 1085    1106148                     Series 7: Intermediate Options     True
# 2866     691760     Ajax  for Beginners: A Very Basic Introduction     True
# 2618    1115222                         Learn and Understand React     True
#
#       price  num_subscribers  num_reviews  num_lectures               level  \
# ...

# %%
df.drop('url',axis=1,inplace=True)

# %%
df.drop('course_id',axis=1,inplace=True)

# %%
df
# Out:
#                                            course_title  is_paid  price  \
# 0                    Ultimate Investment Banking Course     True    200
# 1     Complete GST Course & Certification - Grow You...     True     75
# 2     Financial Modeling for Business Analysts and C...     True     45
# 3     Beginner to Pro - Financial Analysis in Excel ...     True     95
# 4          How To Maximize Your Profits Trading Options     True    200
# ...                                                 ...      ...    ...
# 3673  Learn jQuery from Scratch - Master of JavaScri...     True    100
# 3674  How To Design A WordPress Website With No Codi...     True     25
# 3675                      Learn and Build using Polymer     True     40
# 3676  CSS Animations: Create Amazing Effects on Your...     True     50
# 3677  Using MODX CMS to Build Websites: A Beginner's...     True     45
#
#       num_subscribers  num_reviews  num_lectures               level  \
# ...

# %% [markdown]
# # Convert Object to Date

# %%
df['published_timestamp']=pd.to_datetime(df['published_timestamp'])

# %%
df
# Out:
#                                            course_title  is_paid  price  \
# 0                    Ultimate Investment Banking Course     True    200
# 1     Complete GST Course & Certification - Grow You...     True     75
# 2     Financial Modeling for Business Analysts and C...     True     45
# 3     Beginner to Pro - Financial Analysis in Excel ...     True     95
# 4          How To Maximize Your Profits Trading Options     True    200
# ...                                                 ...      ...    ...
# 3673  Learn jQuery from Scratch - Master of JavaScri...     True    100
# 3674  How To Design A WordPress Website With No Codi...     True     25
# 3675                      Learn and Build using Polymer     True     40
# 3676  CSS Animations: Create Amazing Effects on Your...     True     50
# 3677  Using MODX CMS to Build Websites: A Beginner's...     True     45
#
#       num_subscribers  num_reviews  num_lectures               level  \
# ...

# %%
df.head()
# Out:
#                                         course_title  is_paid  price  \
# 0                 Ultimate Investment Banking Course     True    200
# 1  Complete GST Course & Certification - Grow You...     True     75
# 2  Financial Modeling for Business Analysts and C...     True     45
# 3  Beginner to Pro - Financial Analysis in Excel ...     True     95
# 4       How To Maximize Your Profits Trading Options     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration       published_timestamp           subject
# 0               1.5 2017-01-18 20:58:58+00:00  Business Finance
# ...

# %%
df[df.duplicated()]
# Out:
#                                            course_title  is_paid  price  \
# 787   Essentials of money value: Get a financial Life !     True     20
# 788   Introduction to Forex Trading Business For Beg...     True     20
# 894                  Understanding Financial Statements     True     25
# 1100                  CFA Level 2- Quantitative Methods     True     40
# 1473                             MicroStation - Células     True     20
# 2561  Learn Web Designing & HTML5/CSS3 Essentials in...     True     75
#
#       num_subscribers  num_reviews  num_lectures           level  \
# 787                 0            0            20      All Levels
# 788                 0            0            27  Beginner Level
# 894                 0            0            10      All Levels
# 1100                0            0            35      All Levels
# 1473                0            0             9  Beginner Level
# 2561            43285          525            24      All Levels
#
# ...

# %% [markdown]
# # Remove Duplicated

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [course_title, is_paid, price, num_subscribers, num_reviews, num_lectures, level, content_duration, published_timestamp, subject]
# Index: []

# %% [markdown]
# # Visualie Data
#   - Start with categories
#   - Find relation between columns

# %%
sns.countplot('is_paid',data=df)
plt.title('pais Vs Free Courses') ## most of the courses is paid
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'pais Vs Free Courses')

# %%
df['is_paid'].value_counts()
# Out:
# True     3362
# False     310
# Name: is_paid, dtype: int64

# %%
df['is_paid'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,5))

sns.countplot('level',data=df) # most of the coures is All Level or Beginner

plt.xlabel('levels')
plt.ylabel('Student Count')
plt.title('Courses Levels Vs Student ')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Courses Levels Vs Student ')

# %%
plt.figure(figsize=(8,5))

sns.countplot('subject',data=df) # most of the coures is All Level or Beginner
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='subject', ylabel='count'>

# %%
plt.pie(df['num_subscribers'],labels=df['subject'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fead46dbc70>,
# ...
# ...
#   Text(0.7109305561947661, 0.839391293896119, 'Business Finance'),
#   Text(0.7106151659172513, 0.8396583150117657, 'Business Finance'),
#   Text(0.7105762135501938, 0.8396912794215917, 'Business Finance'),
#   Text(0.7105246499737232, 0.8397349116118242, 'Business Finance'),
#   Text(0.710474660020399, 0.8397772070429743, 'Business Finance'),
#   Text(0.7089760467139594, 0.8410427843967546, 'Business Finance'),
#   Text(0.7075000237168488, 0.8422848190728945, 'Business Finance'),
#   Text(0.7074916669338943, 0.8422918385091357, 'Business Finance'),
#   Text(0.7074643375074905, 0.8423147933849244, 'Business Finance'),
#   Text(0.7074374590802979, 0.842337367976758, 'Business Finance'),
#   Text(0.7074123869575357, 0.8423584241752687, 'Business Finance'),
#   Text(0.707252904559, 0.8424923317116056, 'Business Finance'),
#   Text(0.7067449220717787, 0.8429185103708161, 'Business Finance'),
# ...

# %%
df['subject'].value_counts() # most required fields are web Development and Business Finance
# Out:
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: subject, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # subsribers vs Price

# %%
plt.figure(figsize=(8,6))

sns.regplot(x='price',y='num_subscribers',data=df) # no relation between subsribers and price.
# Out:
# <AxesSubplot:xlabel='price', ylabel='num_subscribers'>

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(x='price',y='num_subscribers',data=df) # no relation between subsribers and price.
# Out:
# <AxesSubplot:xlabel='price', ylabel='num_subscribers'>

# %% [markdown]
# ----

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(x='price',y='num_reviews',data=df) # no relation between num_reviews and price.
# Out:
# <AxesSubplot:xlabel='price', ylabel='num_reviews'>

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(x='price',y='content_duration',data=df) #  relation between content_duration and price.
# Out:
# <AxesSubplot:xlabel='price', ylabel='content_duration'>

# %%
plt.figure(figsize=(8,6))

sns.regplot(x='num_subscribers',y='content_duration',data=df)
#relation between content_duration and num_subscribers.
# Out:
# <AxesSubplot:xlabel='num_subscribers', ylabel='content_duration'>

# %% [markdown]
# # courses : 4 categories
# - visual : number on chart
# - new charts : relation between
# - new

# %%
plt.figure(figsize=(8,5))

sns.countplot('subject',hue='is_paid',data=df) # most of the coures is All Level or Beginner
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='subject', ylabel='count'>

# %%
sns.stripplot(y='subject',x='price',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='subject'>

# %%
plt.figure(figsize=(8,6))

sns.stripplot(y='subject',x='price',hue='is_paid',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='subject'>

# %%
plt.figure(figsize=(8,6))

sns.stripplot(y='subject',x='price',hue='level',data=df,dodge=True)
# Out:
# <AxesSubplot:xlabel='price', ylabel='subject'>
